# %%
# We will examine Turkey
Turkey = {
    "ladder": 79,
    "SD_of_ladder": 58,
    "positive_affect": 154,
    "negative_affect": 121,
    "social_support": 61,
    "freedom": 140,
    "corruption": 50,
    "generosity": 98,
    "log_of_GDP_per_capita": 44,
    "healthy_life_expectancy": 69
}
print(Turkey)
# Out:
# {'ladder': 79, 'SD_of_ladder': 58, 'positive_affect': 154, 'negative_affect': 121, 'social_support': 61, 'freedom': 140, 'corruption': 50, 'generosity': 98, 'log_of_GDP_per_capita': 44, 'healthy_life_expectancy': 69}

# %%
# Now we will examine my home country Azerbaijan
Azerbaijan = {"ladder": 90,
    "SD_of_ladder": 24,
    "positive_affect": 134,
    "negative_affect": 20,
    "social_support": 104,
    "freedom": 101,
    "corruption": 22,
    "generosity": 146,
    "log_of_GDP_per_capita": 65,
    "healthy_life_expectancy": 82
}
print(Azerbaijan)
# Out:
# {'ladder': 90, 'SD_of_ladder': 24, 'positive_affect': 134, 'negative_affect': 20, 'social_support': 104, 'freedom': 101, 'corruption': 22, 'generosity': 146, 'log_of_GDP_per_capita': 65, 'healthy_life_expectancy': 82}

# %%
from matplotlib.pyplot import *
import matplotlib.pyplot as plt

# %%
# Bar graph for Turkey
x = ['Ladder','SD of Ladder','Positive affect','Negative affect','Social support','Freedom','Corruption','Generosity','Log of GDP per capita','Healthy life expectancy']
plt.xticks(rotation=90)
y = [79, 58, 154, 121, 61, 140, 50, 98, 44, 69]

plt.bar(x, y, color='b')
plt.xlabel('Category')
plt.ylabel('Score')
plt.title('Turkey')
plt.show()

# %%
from matplotlib.pyplot import *
import matplotlib.pyplot as plt

# %%
# Bar graph for my home country Azerbaijan

x2 = ['Ladder','SD of Ladder','Positive affect','Negative affect','Social support','Freedom','Corruption','Generosity','Log of GDP per capita','Healthy life expectancy']
plt.xticks(rotation=90)
y2 = [90,24,134,20,104,101,22,146,65,82]

plt.bar(x2, y2, color='g')
plt.xlabel('Category')
plt.ylabel('Score')
plt.title('Azerbaijan')
plt.show()
